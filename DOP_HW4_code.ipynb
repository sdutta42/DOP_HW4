# %% [markdown]
# <a href="https://colab.research.google.com/github/sdutta42/DOP_HW4/blob/main/DOP_HW4_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# contour plot for 2d objective function
from numpy import arange
from numpy import meshgrid
from matplotlib import pyplot

# objective function
def objective(x1, x2):
	return (x1 + 1)**2.0 + (x2 - 2)**2.0

# define range for input
r_min, r_max = -3.0, 5.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 1)
yaxis = arange(r_min, r_max, 1)
# create a mesh from the axis
x1, x2 = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x1, x2)
# create a contour plot with 50 levels and jet color scheme
pyplot.contour(x1, x2, results, 20, alpha=1.0, cmap='jet')
# show the plot
pyplot.show()
pyplot.grid
# Out:
# <function matplotlib.pyplot.grid(b=None, which='major', axis='both', **kwargs)>

# %%
import matplotlib.pyplot as plt
# Construct lines
# x > 0
x = np.linspace(0, 20, 2000)
# y >= 2
y1 = (x*0) + 2
# 2y <= 25 - x
y2 = (25-x)/2.0
# 4y >= 2x - 8 
y3 = (2*x-8)/4.0
# y <= 2x - 5 
y4 = 2 * x -5

# Make plot
plt.plot(x, y1, label=r'$y\geq2')
plt.plot(x, y2, label=r'$2y\leq25-x')
plt.plot(x, y3, label=r'$4y\geq 2x - 8')
plt.plot(x, y4, label=r'$y\leq 2x-5')
plt.xlim((0, 16))
plt.ylim((0, 11))
plt.xlabel(r'$x)
plt.ylabel(r'$y)
# Fill feasible region
y5 = np.minimum(y2, y4)
y6 = np.maximum(y1, y3)
plt.fill_between(x, y5, y6, where=y5>y6, color='grey', alpha=0.5)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# import numpy as np
# import matplotlib.pyplot as plt 

# x = np.linspace(-2,2, 4)
# y = np.linspace(-2,2, 4)

# x1,x2 = np.meshgrid(x,y)

# # objective function
# def objective(x1, x2):
# 	return (x1 + 1)**2.0 + (x2 - 2)**2.0
# Z = objective(x1,x2)
# plt.contour(X, Y, Z, colors='black');
# # plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-4a01717038d8> in <module>
#      11         return (x1 + 1)**2.0 + (x2 - 2)**2.0
#      12 Z = objective(x1,x2)
# ---> 13 plt.contour(X, Y, Z, colors='black');
#      14 # plt.show()
#
# NameError: name 'X' is not defined
